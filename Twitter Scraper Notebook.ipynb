# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /private/var/folders/5_/v97lfq552td0rhx8xkhv2zzm0000gn/T/pip-req-build-k8y9iyiw
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /private/var/folders/5_/v97lfq552td0rhx8xkhv2zzm0000gn/T/pip-req-build-k8y9iyiw
# ...

# %%
import os

# %%
import pandas as pd

# %%
tweet_count = 40000
text_query = "impossible burger"
since_date = "2012-01-01"
until_date = "2021-05-09"

# %%
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> training_tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
tweets_df = pd.read_json('training_tweets.json', lines=True)

# %%
tweets_df
# Out:
#                                                      url  \
# 0      https://twitter.com/yeeurin/status/13911746716...
# 1      https://twitter.com/ThatOlSwain/status/1391163...
# 2      https://twitter.com/DKGuyII1/status/1391161857...
# 3      https://twitter.com/ElGranSenglar/status/13911...
# 4      https://twitter.com/_ramboner_/status/13911510...
# ...                                                  ...
# 39995  https://twitter.com/oh_theogony/status/1212010...
# 39996  https://twitter.com/Mar_de_datos/status/121201...
# 39997  https://twitter.com/coilingoracle/status/12120...
# 39998  https://twitter.com/sophiatseliem/status/12120...
# 39999  https://twitter.com/nighthawk1024/status/12120...
#
#                            date  \
# 0     2021-05-08 23:34:23+00:00
# 1     2021-05-08 22:51:21+00:00
# 2     2021-05-08 22:43:28+00:00
# 3     2021-05-08 22:15:24+00:00
# 4     2021-05-08 22:00:35+00:00
# ...                         ...
# 39995 2019-12-31 13:59:25+00:00
# ...

# %%
tweets_df.to_csv('training_tweets.csv', sep=',', index=False)
